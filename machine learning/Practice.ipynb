# %%
import numpy as np

# %%
arr = np.array([1,2,3,'4'])

# %%
arr
# Out:
# array(['1', '2', '3', '4'], dtype='<U21')

# %%
arr.dtype
# Out:
# dtype('<U21')

# %%
n = int(input())
arr = [6,2,7,3,2]
print(arr)
# Out:
# 1
# [6, 2, 7, 3, 2]

# %%
arr2 = [5,6,7,8,9]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-ecc304234264> in <module>()
#       1 arr2 = [5,6,7,8,9]
#       2
# ----> 3 arr - arr2
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3], [110,130,120])
plt.show()

# %%
x1 = np.array([1,2,3])
x2 = np.array([3,4,5])
y1 = np.array([6,7,8])
y2 = np.array([9,2,3])

plt.xlabel('Name')
plt.ylabel('City')
plt.plot(x1,x2,y1,y2)

# %%
arr3 = np.arange(10,90,20)

# %%
import numpy as np
import matplotlib as plt

# %%
# 문제
import google_drive_downloader as gdd

# %%
# 문제 2
X = np.array([55,55,25,15])
y = np.array(["Apples","Bananas","Cherries","Dates"])
plt.pyplot.boxplot(X,y)
plt.pyplot.show

# %%
# 문제 3
a = [1,2,3,4,5,6,7,8,9]
b = list()
for i in a:
  if i % 2 == 0:
    b[i] = i

print(b)

# %%
# 문제 4
url_str = "http://semyeongcom.hs.kr"
url_name = url_str.split("http://")
url_school = url_name[1].split(".")

print("smc{}{}".format(len(url_school[0]),"@@"))
# Out:
# smc11@@

# %%
import random as rd

a_list = rd

a_list = 
print(a_list)

# %%
X = ["Mon","Tue","Wed","Thu","Fri","Sat","Sun"]
y = [242,255,237,223,264,81,46]

plt.pyplot.scatter(X,y)
plt.pyplot.show
# Out:
# 242
# <function matplotlib.pyplot.show>

# %%
fruit = [{"사과",1000},{"오렌지",880},{"딸기",3700},{"망고",7890}]


for i in fruit:
  print("{}".format(i['사과']))
